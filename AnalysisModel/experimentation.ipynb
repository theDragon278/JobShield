# %%
from src.predict import predict_job

# %%
sample_job = {
    "title": "Work from Home Data Entry",
    "description": "Earn 5000 per day. Registration fee required.",
    "requirements": "Basic typing skills",
    "company_profile": "",
    "benefits": "",
    "industry": "",
    "employment_type": "",
    "location": "",
    "salary_range": ""
}

predict_job(sample_job)
# Out:
# {'model_probability': 0.8572,
#  'rule_score': 0.4,
#  'final_score': 0.7658,
#  'prediction': 'FAKE',
#  'triggered_rules': ['payment_request']}
